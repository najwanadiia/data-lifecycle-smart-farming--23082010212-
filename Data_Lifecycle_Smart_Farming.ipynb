# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-220a4981-ff77-4b1a-a2c6-f10e991c6d07" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-220a4981-ff77-4b1a-a2c6-f10e991c6d07">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d amirmohammdjalili/soil-moisture-dataset
# !unzip soil-moisture-dataset.zip
# Out:
# Dataset URL: https://www.kaggle.com/datasets/amirmohammdjalili/soil-moisture-dataset
# License(s): unknown
# ...
#   0% 0.00/90.9k [00:00<?, ?B/s]
# 100% 90.9k/90.9k [00:00<00:00, 172MB/s]
# Archive:  soil-moisture-dataset.zip
#   inflating: plant_vase1(2).CSV
#   inflating: plant_vase1.CSV
#   inflating: plant_vase2.CSV

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import glob

print("File ditemukan:", semua_file)

if semua_file:
    df = pd.read_csv(semua_file[0])
else:
    print("Tidak ada file CSV ditemukan!")

print("--- Cek missing values ---")
print(df.isnull().sum())

plt.figure(figsize=(10,4))
plt.plot(df['moisture0'].head(100), label='Moisture Level 0', color='brown')
plt.plot(df['moisture1'].head(100), label='Moisture Level 1', color='teal')
plt.title('Tren Kelembaban Tanah (100 Data Pertama)')
plt.legend()
plt.show()

plt.figure(figsize=(8,6))

kolom_angka = df.select_dtypes(include=['number'])
sns.heatmap(kolom_angka.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Heatmap Korelasi Dataset 2')
plt.show()

df.to_csv('cleaned_data.csv', index=False)
print("\nBeres, file cleaned_data.csv untuk Dataset 2 udah disave!")
# Out:
# File ditemukan: []
# Tidak ada file CSV ditemukan!
# --- Cek missing values ---
# year         0
# month        0
# day          0
# hour         0
# minute       0
# second       0
# moisture0    0
# moisture1    0
# moisture2    0
# moisture3    0
# moisture4    0
# irrgation    0
# dtype: int64
# Beres, file cleaned_data.csv untuk Dataset 2 udah disave!
